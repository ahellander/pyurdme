# %%
import pyurdme
from matplotlib import cm as CM
from IPython.display import display, clear_output
import time

# %%
from coral import CoralReef

# %%
model = CoralReef()
result = pyurdme.urdme(model)
# Out:
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:FFC:Reusing form from cache.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:FFC:Reusing form from cache.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:FFC:Reusing form from cache.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:UFL:No integrals left after transformation, returning empty form.
# DEBUG:FFC:Reusing form from cache.

# %%
x_vals = model.mesh.coordinates()[:, 0]
y_vals = model.mesh.coordinates()[:, 1]
z_vals = result.getSpecies("Coral")
num_vox = len(x_vals)

# %%
for tndx, tval in enumerate(model.tspan):
    heatmap, xedges, yedges = np.histogram2d(x=x_vals, y=y_vals, weights=z_vals[tndx,:], bins=int(sqrt(num_vox)))
    #heatmap
    #fig = plt.figure(figsize=(8,6), dpi=100)
    plt.imshow(heatmap)
    cb = plt.colorbar()
    cb.set_label('molecule population')
    plt.title('t={0}'.format(tval))
    clear_output()
    plt.show()
    time.sleep(.01)
