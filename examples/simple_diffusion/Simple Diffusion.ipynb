# %%
import pyurdme
from simple_diffusion2 import simple_diffusion2

# %%
model = simple_diffusion2()
result = pyurdme.urdme(model)

# %%
result.display("A",49)
# Out:
# <div id="f5ab6571-5749-4a8a-aff6-d13ee79a615d" class="cell"></div><script>
# ...

# %%
model.mesh
# Out:
# <div id="3f4c2016-0ac1-40d9-9734-e13d4ba00668" class="cell"></div><script>
# ...

# %%
A = result.get_species("A",49)

# %%
import numpy
numpy.shape(A)
# Out:
# (1801,)

# %%
A[0:10]
# Out:
# array([ 1.,  1.,  1.,  1.,  0.,  2.,  0.,  4.,  0.,  0.])
